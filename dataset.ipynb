# %%
import obspy
from obspy.clients.fdsn.mass_downloader import CircularDomain, Restrictions, MassDownloader
import obspy
import numpy as np
import pandas as pd
from obspy import read
from obspy.core import Stream
import glob
import os
from scipy import signal
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import obspy
#       2 from obspy.clients.fdsn.mass_downloader import CircularDomain, Restrictions, MassDownloader
#       3 import obspy
#
# ModuleNotFoundError: No module named 'obspy'

# %%
# Program 1: P-Wave Early Detection
def download_early_pwave_data(event_time, latitude, longitude):
    domain = CircularDomain(
        latitude=latitude,
        longitude=longitude,
        minradius=0.0,
        maxradius=10.0 # 10 degrees (~1100 km)
    )
    restrictions = Restrictions(
        starttime=event_time - 30, # 30 seconds before
        endtime=event_time + 120,
        # 2 minutes after
        reject_channels_with_gaps=True,
        minimum_length=0.95,
        minimum_interstation_distance_in_m=5000, # 5 km minimum spacing
        # Prioritize high sample rate channels
        channel_priorities=["HH[ZNE]", "BH[ZNE]", "EH[ZNE]"],
        location_priorities=["", "00", "10"],
        # Additional parameters for data quality
        # minimum_sample_rate=100.0 # Ensure high sampling rate
    )
    mdl = MassDownloader()
    mdl.download(
        domain,
        restrictions,
        mseed_storage="waveforms_pwave",
        stationxml_storage="stations_pwave"
    )

# %%
# Program 2: Ground Motion Prediction
def download_ground_motion_data(event_time, latitude, longitude):
    domain = CircularDomain(
        latitude=latitude,
        longitude=longitude,
        minradius=0.0,
        maxradius=20.0 # 20 degrees (~2200 km)
    )
    restrictions = Restrictions(
        starttime=event_time - 60, # 1 minute before
        endtime=event_time + 600, # 10 minutes after
        reject_channels_with_gaps=True,
        minimum_length=0.90,
        minimum_interstation_distance_in_m=20000, # 20 km minimum spacing
        # Include strong motion channels
        channel_priorities=["HN[ZNE]", "HH[ZNE]", "BH[ZNE]"],
        location_priorities=["", "00", "10"],
        # Less strict on sample rate for surface waves
        # minimum_sample_rate=50.0
    )
    mdl = MassDownloader()
    mdl.download(
        domain,
        restrictions,
        mseed_storage="waveforms_motion",
        stationxml_storage="stations_motion"
    )

# %%
# Program 3: Aftershock Analysis
def download_aftershock_data(event_time, latitude, longitude):
  domain = CircularDomain(
    latitude=latitude,
    longitude=longitude,
    minradius=0.0,
    maxradius=15.0 # 15 degrees (~1650 km)
  )
  restrictions = Restrictions(
    starttime=event_time, # Start at mainshock
    endtime=event_time + 30 * 86400,
    # 30 days after
    reject_channels_with_gaps=False,
    # Allow some gaps due to long duration
    minimum_length=0.70,
    # More lenient minimum length
    minimum_interstation_distance_in_m=50000, # 50 km minimum spacing
    # Include broader range of channels
    channel_priorities=["HH[ZNE]", "BH[ZNE]", "HN[ZNE]", "EH[ZNE]"],
    location_priorities=["", "00", "10"],
    # Less strict on sample rate
    minimum_sample_rate=20.0
  )
  mdl = MassDownloader()
  mdl.download(
    domain,
    restrictions,
    mseed_storage="waveforms_aftershock",
    stationxml_storage="stations_aftershock"
  )# Example event (2011 Tohoku earthquake)
event_time = obspy.UTCDateTime(2011, 3, 11, 5, 47, 32)
event_latitude = 37.52
event_longitude = 143.04
# Download data for each analysis type
download_ground_motion_data(event_time, event_latitude, event_longitude)

# %%
# Example event (2011 Tohoku earthquake)
event_time = obspy.UTCDateTime(2011, 3, 11, 5, 47, 32)
event_latitude = 37.52
event_longitude = 143.04
# Download data for each analysis type
download_ground_motion_data(event_time, event_latitude, event_longitude)
# Out:
# [2025-02-15 15:30:56,246] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for AUSPASS, BGR, EIDA, EMSC, ETH, GEOFON, GEONET, GFZ, ICGC, IESDMC, INGV, IPGP, ISC, KNMI, KOERI, LMU, NCEDC, NIEP, NOA, RESIF, RESIFPH5, SCEDC, TEXNET, UIB-NORSAR, USGS, USP, ORFEUS, IRIS.
# [2025-02-15 15:30:56,849] - obspy.clients.fdsn.mass_downloader - INFO: Cannot use client 'ISC' as it does not have 'dataselect' and/or 'station' services.
# [2025-02-15 15:30:56,895] - obspy.clients.fdsn.mass_downloader - INFO: Cannot use client 'USGS' as it does not have 'dataselect' and/or 'station' services.
# [2025-02-15 15:30:57,372] - obspy.clients.fdsn.mass_downloader - INFO: Cannot use client 'EMSC' as it does not have 'dataselect' and/or 'station' services.
# [2025-02-15 15:30:57,591] - obspy.clients.fdsn.mass_downloader - INFO: Cannot use client 'RESIFPH5' as it does not have 'dataselect' and/or 'station' services.
# [2025-02-15 15:30:57,894] - obspy.clients.fdsn.mass_downloader - WARNING: Failed to initialize client 'IESDMC'.
# [2025-02-15 15:31:05,169] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 23 client(s): AUSPASS, BGR, EIDA, ETH, GEOFON, GEONET, GFZ, ICGC, INGV, IPGP, KNMI, KOERI, LMU, NCEDC, NIEP, NOA, RESIF, SCEDC, TEXNET, UIB-NORSAR, USP, ORFEUS, IRIS.
# [2025-02-15 15:31:05,175] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:31:05,178] - obspy.clients.fdsn.mass_downloader - INFO: Client 'AUSPASS' - Requesting reliable availability.
# [2025-02-15 15:31:05,533] - obspy.clients.fdsn.mass_downloader - INFO: Client 'AUSPASS' - No data available for request.
# [2025-02-15 15:31:05,535] - obspy.clients.fdsn.mass_downloader - INFO: Client 'AUSPASS' - No data available.
# [2025-02-15 15:31:05,539] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:31:05,540] - obspy.clients.fdsn.mass_downloader - INFO: Client 'BGR' - Requesting unreliable availability.
# [2025-02-15 15:31:05,789] - obspy.clients.fdsn.mass_downloader - INFO: Client 'BGR' - No data available for request.
# [2025-02-15 15:31:05,790] - obspy.clients.fdsn.mass_downloader - INFO: Client 'BGR' - No data available.
# [2025-02-15 15:31:05,791] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:31:05,793] - obspy.clients.fdsn.mass_downloader - INFO: Client 'EIDA' - Requesting unreliable availability.
# [2025-02-15 15:33:06,004] - obspy.clients.fdsn.mass_downloader - ERROR: Client 'EIDA' - Failed getting availability due to unexpected exception: 'TimeoutError' object has no attribute 'splitlines'
# [2025-02-15 15:33:06,006] - obspy.clients.fdsn.mass_downloader - INFO: Client 'EIDA' - No data available.
# [2025-02-15 15:33:06,008] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:33:06,011] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ETH' - Requesting unreliable availability.
# [2025-02-15 15:33:06,511] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ETH' - No data available for request.
# [2025-02-15 15:33:06,513] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ETH' - No data available.
# [2025-02-15 15:33:06,514] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:33:06,515] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEOFON' - Requesting unreliable availability.
# [2025-02-15 15:33:11,001] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEOFON' - No data available for request.
# [2025-02-15 15:33:11,002] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEOFON' - No data available.
# [2025-02-15 15:33:11,005] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:33:11,011] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEONET' - Requesting unreliable availability.
# [2025-02-15 15:33:11,295] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEONET' - No data available for request.
# [2025-02-15 15:33:11,298] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GEONET' - No data available.
# [2025-02-15 15:33:11,301] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:33:11,303] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - Requesting unreliable availability.
# [2025-02-15 15:33:16,442] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - No data available for request.
# [2025-02-15 15:33:16,443] - obspy.clients.fdsn.mass_downloader - INFO: Client 'GFZ' - No data available.
# [2025-02-15 15:33:16,447] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:33:16,449] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ICGC' - Requesting unreliable availability.
# [2025-02-15 15:33:16,822] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ICGC' - No data available for request.
# [2025-02-15 15:33:16,823] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ICGC' - No data available.
# [2025-02-15 15:33:16,824] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:33:16,826] - obspy.clients.fdsn.mass_downloader - INFO: Client 'INGV' - Requesting unreliable availability.
# [2025-02-15 15:33:23,084] - obspy.clients.fdsn.mass_downloader - INFO: Client 'INGV' - No data available for request.
# [2025-02-15 15:33:23,086] - obspy.clients.fdsn.mass_downloader - INFO: Client 'INGV' - No data available.
# [2025-02-15 15:33:23,088] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2025-02-15 15:33:23,090] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Requesting unreliable availability.
# [2025-02-15 15:33:23,750] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Successfully requested availability (0.66 seconds)
# [2025-02-15 15:33:23,754] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Found 1 stations (3 channels).
# [2025-02-15 15:33:23,758] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Will attempt to download data from 1 stations.
# [2025-02-15 15:33:23,761] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Status for 3 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2025-02-15 15:33:24,607] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Successfully downloaded 3 channels (of 3)
# [2025-02-15 15:33:24,610] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Launching basic QC checks...
# [2025-02-15 15:33:24,632] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Downloaded 0.2 MB [199.29 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2025-02-15 15:33:24,634] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Status for 3 time intervals/channels after downloading: DOWNLOADED
# [2025-02-15 15:33:24,918] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Successfully downloaded 'stations_motion/G.INU.xml'.
# [2025-02-15 15:33:24,925] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IPGP' - Downloaded 1 station files [0.0 MB] in 0.3 seconds [84.72 KB/sec].
# [2025-02-15 15:33:24,931] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:33:24,932] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KNMI' - Requesting unreliable availability.
# [2025-02-15 15:33:25,360] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KNMI' - No data available for request.
# [2025-02-15 15:33:25,361] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KNMI' - No data available.
# [2025-02-15 15:33:25,363] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:33:25,365] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KOERI' - Requesting unreliable availability.
# [2025-02-15 15:33:31,447] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KOERI' - No data available for request.
# [2025-02-15 15:33:31,449] - obspy.clients.fdsn.mass_downloader - INFO: Client 'KOERI' - No data available.
# [2025-02-15 15:33:31,452] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:33:31,453] - obspy.clients.fdsn.mass_downloader - INFO: Client 'LMU' - Requesting unreliable availability.
# [2025-02-15 15:33:32,024] - obspy.clients.fdsn.mass_downloader - INFO: Client 'LMU' - No data available for request.
# [2025-02-15 15:33:32,025] - obspy.clients.fdsn.mass_downloader - INFO: Client 'LMU' - No data available.
# [2025-02-15 15:33:32,027] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:33:32,028] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NCEDC' - Requesting unreliable availability.
# [2025-02-15 15:33:49,896] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NCEDC' - No data available for request.
# [2025-02-15 15:33:49,898] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NCEDC' - No data available.
# [2025-02-15 15:33:49,899] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:33:49,901] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NIEP' - Requesting unreliable availability.
# [2025-02-15 15:33:50,934] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NIEP' - No data available for request.
# [2025-02-15 15:33:50,936] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NIEP' - No data available.
# [2025-02-15 15:33:50,937] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:33:50,939] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NOA' - Requesting unreliable availability.
# [2025-02-15 15:34:02,731] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NOA' - No data available for request.
# [2025-02-15 15:34:02,732] - obspy.clients.fdsn.mass_downloader - INFO: Client 'NOA' - No data available.
# [2025-02-15 15:34:02,734] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:34:02,735] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - Requesting reliable availability.
# [2025-02-15 15:34:03,946] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - Successfully requested availability (1.21 seconds)
# [2025-02-15 15:34:03,949] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - Found 1 stations (3 channels).
# [2025-02-15 15:34:03,951] - obspy.clients.fdsn.mass_downloader - INFO: Client 'RESIF' - No new data available after discarding already downloaded data.
# [2025-02-15 15:34:03,954] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:34:03,955] - obspy.clients.fdsn.mass_downloader - INFO: Client 'SCEDC' - Requesting unreliable availability.
# [2025-02-15 15:34:20,144] - obspy.clients.fdsn.mass_downloader - INFO: Client 'SCEDC' - No data available for request.
# [2025-02-15 15:34:20,146] - obspy.clients.fdsn.mass_downloader - INFO: Client 'SCEDC' - No data available.
# [2025-02-15 15:34:20,148] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:34:20,150] - obspy.clients.fdsn.mass_downloader - INFO: Client 'TEXNET' - Requesting unreliable availability.
# [2025-02-15 15:34:20,247] - obspy.clients.fdsn.mass_downloader - INFO: Client 'TEXNET' - No data available for request.
# [2025-02-15 15:34:20,248] - obspy.clients.fdsn.mass_downloader - INFO: Client 'TEXNET' - No data available.
# [2025-02-15 15:34:20,251] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:34:20,252] - obspy.clients.fdsn.mass_downloader - INFO: Client 'UIB-NORSAR' - Requesting unreliable availability.
# [2025-02-15 15:34:20,885] - obspy.clients.fdsn.mass_downloader - INFO: Client 'UIB-NORSAR' - No data available for request.
# [2025-02-15 15:34:20,886] - obspy.clients.fdsn.mass_downloader - INFO: Client 'UIB-NORSAR' - No data available.
# [2025-02-15 15:34:20,889] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:34:20,891] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Requesting unreliable availability.
# [2025-02-15 15:34:21,935] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Successfully requested availability (1.04 seconds)
# [2025-02-15 15:34:21,937] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Found 1 stations (1 channels).
# [2025-02-15 15:34:21,940] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Will attempt to download data from 1 stations.
# [2025-02-15 15:34:21,941] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Status for 1 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2025-02-15 15:34:22,653] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - No data available for request.
# HTTP Status code: 204
# [2025-02-15 15:34:22,656] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Launching basic QC checks...
# [2025-02-15 15:34:22,657] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2025-02-15 15:34:22,658] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - Status for 1 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2025-02-15 15:34:22,661] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - No station information to download.
# [2025-02-15 15:34:22,662] - obspy.clients.fdsn.mass_downloader - INFO: Client 'USP' - No data could be downloaded.
# [2025-02-15 15:34:22,666] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:34:22,667] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ORFEUS' - Requesting unreliable availability.
# [2025-02-15 15:34:23,177] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ORFEUS' - No data available for request.
# [2025-02-15 15:34:23,178] - obspy.clients.fdsn.mass_downloader - INFO: Client 'ORFEUS' - No data available.
# [2025-02-15 15:34:23,180] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 1
# [2025-02-15 15:34:23,181] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Requesting reliable availability.
# [2025-02-15 15:34:26,187] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully requested availability (3.00 seconds)
# [2025-02-15 15:34:26,372] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Found 127 stations (377 channels).
# [2025-02-15 15:34:26,439] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Will attempt to download data from 125 stations.
# [2025-02-15 15:34:26,456] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Status for 371 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2025-02-15 15:34:33,115] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 38 channels (of 50)
# [2025-02-15 15:34:33,713] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 44 channels (of 50)
# [2025-02-15 15:34:34,710] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 50 channels (of 50)
# [2025-02-15 15:34:40,237] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 38 channels (of 50)
# [2025-02-15 15:34:40,788] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded 38 channels (of 50)
# [2025-02-15 15:34:42,694] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Successfully downloaded
- obspy.clients.fdsn.mass_downloader - INFO: Client 'IRIS' - Acquired 104 StationXML files [5.1 MB].
# [2025-02-15 15:34:56,108] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 23.3 MB in total.

# %%
def process_station_metadata(station_dir):
    """
    Process station XML files to extract station metadata
    """
    metadata = []
    for xml_file in glob.glob(os.path.join(station_dir, "*.xml")):
        inventory = obspy.read_inventory(xml_file)
        for network in inventory:
            for station in network:
                station_info = {
                    'station_id': f"{network.code}.{station.code}",
                    'latitude': station.latitude,
                    'longitude': station.longitude,
                    'elevation': station.elevation,
                    'distance_to_event': None  # Will be calculated later
                }
                metadata.append(station_info)
    return pd.DataFrame(metadata)

def process_waveforms(waveform_dir, sampling_rate=100.0, window_size=60):
    """
    Process MSEED waveform files into fixed-length windows
    """
    features = []
    for mseed_file in glob.glob(os.path.join(waveform_dir, "*.mseed")):
        try:
            # Read the stream
            st = read(mseed_file)

            # Process each trace in the stream
            for tr in st:
                # Preprocess the trace
                tr = preprocess_trace(tr, sampling_rate)

                # Extract windows
                windows = extract_windows(tr, window_size, sampling_rate)

                for window in windows:
                    feature_dict = extract_features(window)
                    feature_dict.update({
                        'station_id': f"{tr.stats.network}.{tr.stats.station}",
                        'channel': tr.stats.channel,
                        'start_time': tr.stats.starttime
                    })
                    features.append(feature_dict)

        except Exception as e:
            print(f"Error processing {mseed_file}: {str(e)}")
            continue

    return pd.DataFrame(features)

def preprocess_trace(trace, sampling_rate):
    """
    Preprocess a single seismic trace
    """
    trace = trace.copy()

    # Remove mean and trend
    trace.detrend('demean')
    trace.detrend('linear')

    # Resample if necessary
    if trace.stats.sampling_rate != sampling_rate:
        trace.resample(sampling_rate)

    # Taper edges
    trace.taper(max_percentage=0.05, type='hann')

    return trace

def extract_windows(trace, window_size, sampling_rate):
    """
    Extract fixed-length windows from a trace
    """
    # Calculate number of samples per window
    samples_per_window = int(window_size * sampling_rate)

    # Get data array
    data = trace.data

    # Split into windows
    windows = []
    for i in range(0, len(data) - samples_per_window, samples_per_window):
        window = data[i:i + samples_per_window]
        if len(window) == samples_per_window:
            windows.append(window)

    return windows

def extract_features(window):
    """
    Extract features from a window of seismic data
    """
    features = {
        # Time domain features
        'mean': np.mean(window),
        'std': np.std(window),
        'max': np.max(np.abs(window)),
        'peak_to_peak': np.ptp(window),
        'rms': np.sqrt(np.mean(np.square(window))),

        # Frequency domain features
        'dominant_freq': compute_dominant_frequency(window),
        'spectral_centroid': compute_spectral_centroid(window),

        # Energy features
        'energy': np.sum(np.square(window)),

        # Store raw waveform for ML model
        'waveform': window.tolist()
    }
    return features

def compute_dominant_frequency(window, fs=100.0):
    """
    Compute the dominant frequency in a window
    """
    freqs, psd = signal.welch(window, fs=fs)
    return freqs[np.argmax(psd)]

def compute_spectral_centroid(window, fs=100.0):
    """
    Compute the spectral centroid of a window
    """
    freqs, psd = signal.welch(window, fs=fs)
    return np.sum(freqs * psd) / np.sum(psd)

def create_ml_dataset(waveform_dir, station_dir, event_coords):
    """
    Create complete dataset for ML modeling
    """
    # Process station metadata
    station_df = process_station_metadata(station_dir)

    # Calculate distances to event
    for idx, row in station_df.iterrows():
        station_df.loc[idx, 'distance_to_event'] = obspy.geodetics.locations2degrees(
            event_coords['latitude'],
            event_coords['longitude'],
            row['latitude'],
            row['longitude']
        )

    # Process waveforms and extract features
    features_df = process_waveforms(waveform_dir)

    # Merge station metadata with features
    final_df = features_df.merge(station_df, on='station_id')

    return final_df

# Example usage
event_coords = {
    'latitude': 37.52,
    'longitude': 143.04
}

dataset = create_ml_dataset(
    waveform_dir="waveforms_motion",
    station_dir="stations_motion",
    event_coords=event_coords
)
# Out:
# <ipython-input-8-978420cc01b4>:136: RuntimeWarning: invalid value encountered in scalar divide
#   return np.sum(freqs * psd) / np.sum(psd)

# %%
dataset.to_csv('dataset.csv', index=False)
dataset = pd.read_csv('dataset.csv')

def clean_seismic_dataset(df):
    """
    Clean and prepare seismic dataset for ML modeling
    """
    # Create a copy to avoid modifying original data
    df_clean = df.copy()

    # Convert mean to float64
    df_clean['mean'] = pd.to_numeric(df_clean['mean'], errors='coerce')

    # Convert start_time to datetime
    df_clean['start_time'] = pd.to_datetime(df_clean['start_time'])

    # Convert waveform from string/object to numpy arrays
    df_clean['waveform'] = df_clean['waveform'].apply(lambda x: np.array(x) if isinstance(x, list) else x)

    # Drop any rows with missing values
    df_clean = df_clean.dropna()

    # Create feature matrix X and target y (example using PGA prediction)
    feature_columns = [
        'mean', 'std', 'max', 'peak_to_peak', 'rms',
        'dominant_freq', 'spectral_centroid', 'energy',
        'latitude', 'longitude', 'elevation', 'distance_to_event'
    ]

    # Encode categorical variables
    df_clean['channel_encoded'] = pd.Categorical(df_clean['channel']).codes
    feature_columns.append('channel_encoded')

    # Create time-based features
    df_clean['hour'] = df_clean['start_time'].dt.hour
    df_clean['minute'] = df_clean['start_time'].dt.minute
    feature_columns.extend(['hour', 'minute'])

    # Scale numerical features
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    df_clean[feature_columns] = scaler.fit_transform(df_clean[feature_columns])

    # Create feature matrix
    X = df_clean[feature_columns]

    # For demonstration, let's use 'max' as target (you can modify based on your needs)
    y = df_clean['max']

    # Create metadata dictionary for reference
    metadata = {
        'feature_columns': feature_columns,
        'scaler': scaler,
        'station_ids': df_clean['station_id'].unique(),
        'channels': df_clean['channel'].unique(),
        'time_range': (df_clean['start_time'].min(), df_clean['start_time'].max())
    }

    return X, y, metadata

def split_seismic_dataset(X, y, test_size=0.2, random_state=42):
    """
    Split dataset while ensuring no station data leakage
    """
    from sklearn.model_selection import train_test_split

    # Split while maintaining temporal order
    train_idx = int(len(X) * (1 - test_size))

    X_train = X.iloc[:train_idx]
    X_test = X.iloc[train_idx:]
    y_train = y.iloc[:train_idx]
    y_test = y.iloc[train_idx:]

    return X_train, X_test, y_train, y_test

# Example usage
# Assuming your DataFrame is called 'dataset'
X, y, metadata = clean_seismic_dataset(dataset)
X_train, X_test, y_train, y_test = split_seismic_dataset(X, y)

print("Dataset shapes:")
print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
print("\nFeatures used:", metadata['feature_columns'])
dataset
# Out:
# Dataset shapes:
# X_train: (557, 15)
# X_test: (140, 15)
#
# Features used: ['mean', 'std', 'max', 'peak_to_peak', 'rms', 'dominant_freq', 'spectral_centroid', 'energy', 'latitude', 'longitude', 'elevation', 'distance_to_event', 'channel_encoded', 'hour', 'minute']
#                     mean           std           max  peak_to_peak  \
# 0     199.88429148806142  2.621904e+02  5.679320e+02  1.015781e+03
